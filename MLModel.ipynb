# %%
import spacy
import pandas as pd
from spacy_cld import LanguageDetector

# %%
# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load('en_core_web_sm')

# Process whole documents
text = (u"When Sebastian Thrun started working on self-driving cars at "
        u"Google in 2007, few people outside of the company took him "
        u"seriously. “I can tell you very senior CEOs of major American "
        u"car companies would shake my hand and turn away because I wasn’t "
        u"worth talking to,” said Thrun, now the co-founder and CEO of "
        u"online higher education startup Udacity, in an interview with "
        u"Recode earlier this week.")
doc = nlp(text)

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)

# Determine semantic similarities
doc1 = nlp(u"my fries were super gross")
doc2 = nlp(u"such disgusting fries")
similarity = doc1.similarity(doc2)
print(doc1.text, doc2.text, similarity)

# %%
dataset = pd.read_csv("sample.csv")

# %%
nlp = spacy.load('en_core_web_sm')
doc1 = nlp(u"Narcos")

for index, row in dataset.iterrows():
    print ("Data:{}".format(row.values[0]))
    row_nlp = nlp(row.values[0])
    similarity = row_nlp.similarity(doc1)
    print ("Similarity:{}".format(similarity))
    for entity in row_nlp.ents:
        print("    Entity: {} - {} - {}".format(entity.text, entity.label_,similarity))
# Out:
# Data:Dragon-Ball-Super-S04E28-DUBBED-720p-HDTV-x264-CRiMSON[rarbg]
# Similarity:0.2638716423413313
# Data:Dragon-Ball-Super-S04E13-DUBBED-720p-HDTV-x264-CRiMSON[rarbg]
# Similarity:0.24462472231096813
# Data:Dragon-Ball-Super-92-Eng-Sub-720p-2CH-AAC-x265-HEVC-INC[UTR]
# Similarity:0.20059567383611027
# Data:Dragon-Ball-Super-S04E19-DUBBED-1080p-HDTV-x264-W4F[rarbg]
# Similarity:0.23081996290011902
# Data:Dragon-Ball-Super-E108-1080p-WEB-DL-H264-DUAL-WWW-COMANDOTORRENTS-COM
# Similarity:0.2518026682828698
#     Entity: WWW - ORG - 0.2518026682828698
# Data:Dragon-Ball-Super-S04E16-DUBBED-720p-HDTV-x264-CRiMSON[rarbg]
# Similarity:0.2444498718400148
# Data:Dragon-Ball-Super-S05E13-DUBBED-HDTV-x264-CRiMSON[rarbg]
# Similarity:0.23733002571482575
# Data:Dragon-Ball-Super-S04E26-DUBBED-720p-HDTV-x264-CRiMSON[rarbg]
# Similarity:0.22214745461855737
# Data:[Funimation-DUB]-Dragon-Ball-Super--83-[1080p][EXIL3]
# Similarity:0.2640562016340498
# Data:[ACESSE-MEGAFILMESTORRENTS-ORG]-Dragon-Ball-Super-E73-720p-WEB-DL-H264-DUAL-iZARDs
# Similarity:0.214045874097137
# Data:WWW-BLUDV-TV -Dragon-Ball-Super-2018--Episodio-69-(1080p)-Acesse-o-ORIGINAL-WWW-BLUDV-TV
# Similarity:0.19893665810573508
#     Entity: WWW-BLUDV-TV - ORG - 0.19893665810573508
# Data:Dragon-Ball-Super-Complete-Season-2-1080P-BluRay-UNCUT
# Similarity:0.28615823065198237
# Data:Dragon-Ball-Super-Complete-Season-3-1080P-BluRay-UNCUT
# Similarity:0.2880947250642325
# Data:[HorribleSubs] Boruto - Naruto Next Generations - 35 (1080p)
# Similarity:0.3161278623927741
#     Entity: HorribleSubs - ORG - 0.3161278623927741
#     Entity: Boruto - Naruto Next Generations - 35 ( - ORG - 0.3161278623927741
# Data:Boruto - Naruto Next Generations - 08
# Similarity:0.37802128457420614
#     Entity: Boruto - Naruto Next Generations - - ORG - 0.37802128457420614
# Data:[HorribleSubs] Boruto - Naruto Next Generations - 55 [480p]
# Similarity:0.29278919198344383
#     Entity: HorribleSubs - ORG - 0.29278919198344383
#     Entity: Boruto - Naruto Next Generations - ORG - 0.29278919198344383
# Data:Boruto - 072 [JesuSub] vostfr 1080p x265 AAC mp4
# Similarity:0.3543566172079165
#     Entity: Boruto - 072 - ORG - 0.3543566172079165
#     Entity: JesuSub - ORG - 0.3543566172079165
#     Entity: 1080p - PRODUCT - 0.3543566172079165
#     Entity: AAC - ORG - 0.3543566172079165
# Data:Boruto - 074 [JesuSub] vostfr 1080p x265 AAC mp4
# Similarity:0.37278191361394686
#     Entity: JesuSub - ORG - 0.37278191361394686
#     Entity: 1080p - PRODUCT - 0.37278191361394686
#     Entity: AAC - ORG - 0.37278191361394686
# Data:Catfish - 121 [sometinghere] vostfr 1080p x265 AAC mp4
# Similarity:0.30468072401974816
#     Entity: 1080p - DATE - 0.30468072401974816
#     Entity: AAC - ORG - 0.30468072401974816
# Data:Boruto Naruto Next Generations E10 DUBBED HDTV x264-W4F
# Similarity:0.39228597138368554
#     Entity: Boruto Naruto Next Generations - ORG - 0.39228597138368554
# Data:Boruto - 009 vostfr X265 1080p mp4
# Similarity:0.4207954462591315
#     Entity: 009 - CARDINAL - 0.4207954462591315
#     Entity: X265 1080p mp4 - PRODUCT - 0.4207954462591315
# Data:Boruto Naruto Next Generations - 25
# Similarity:0.3917431809112038
#     Entity: Boruto Naruto Next Generations - 25 - ORG - 0.3917431809112038
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [65-77] (2018) WEBRip 1080p | ColdFilm
# Similarity:0.3917838686904851
#     Entity: Боруто: - ORG - 0.3917838686904851
#     Entity: Naruto Next Generations - ORG - 0.3917838686904851
#     Entity: 65-77 - DATE - 0.3917838686904851
#     Entity: 2018 - DATE - 0.3917838686904851
#     Entity: WEBRip - ORDINAL - 0.3917838686904851
#     Entity: 1080p - DATE - 0.3917838686904851
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [65-80] (2018) WEBRip 1080p | ColdFilm
# Similarity:0.3919742355476551
#     Entity: Боруто: - ORG - 0.3919742355476551
#     Entity: Naruto Next Generations - ORG - 0.3919742355476551
#     Entity: 65-80 - DATE - 0.3919742355476551
#     Entity: 2018 - DATE - 0.3919742355476551
#     Entity: WEBRip - ORDINAL - 0.3919742355476551
#     Entity: 1080p - DATE - 0.3919742355476551
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [65-78] (2018) WEBRip | ColdFilm
# Similarity:0.3777122411251535
#     Entity: Боруто: - ORG - 0.3777122411251535
#     Entity: Naruto Next Generations - ORG - 0.3777122411251535
#     Entity: 65-78 - DATE - 0.3777122411251535
#     Entity: 2018 - DATE - 0.3777122411251535
#     Entity: WEBRip - GPE - 0.3777122411251535
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [01x01-07 из 13] (2017) WEBRip 720p | ViruseProject
# Similarity:0.4116098544529459
#     Entity: Боруто: - ORG - 0.4116098544529459
#     Entity: 13] - DATE - 0.4116098544529459
#     Entity: WEBRip 720p - CARDINAL - 0.4116098544529459
# Data:[HorribleSubs] Boruto - Naruto Next Generations - 61 (1080p)
# Similarity:0.29139202766193445
#     Entity: HorribleSubs - ORG - 0.29139202766193445
#     Entity: Boruto - Naruto Next Generations - 61 ( - ORG - 0.29139202766193445
# Data:Boruto - 058 [JesuSub] vostfr 1080p x265 AAC mp4
# Similarity:0.3489316207598083
#     Entity: Boruto - 058 - ORG - 0.3489316207598083
#     Entity: JesuSub - ORG - 0.3489316207598083
#     Entity: 1080p - PRODUCT - 0.3489316207598083
#     Entity: AAC - ORG - 0.3489316207598083
# Data:Boruto - Naruto Next Generations S01E13 [720p] [LEG] - COMANDOTORRENTS COM
# Similarity:0.449483869154684
#     Entity: Boruto - Naruto Next Generations S01E13 - ORG - 0.449483869154684
#     Entity: 720p - CARDINAL - 0.449483869154684
#     Entity: LEG - ORG - 0.449483869154684
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [01-04 из 13] (2017) HDTVRip 720p | SEKAI PROJECT
# Similarity:0.39620489072097004
#     Entity: Боруто: - ORG - 0.39620489072097004
#     Entity: Naruto Next Generations - ORG - 0.39620489072097004
#     Entity: 01-04 - DATE - 0.39620489072097004
#     Entity: 13 - CARDINAL - 0.39620489072097004
#     Entity: 720p - CARDINAL - 0.39620489072097004
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [01-20 из 26] (2017) HDTVRip 720p | Shiza Project & KANSAI Studio
# Similarity:0.3704803554546018
#     Entity: Боруто: - ORG - 0.3704803554546018
#     Entity: Naruto Next Generations - ORG - 0.3704803554546018
#     Entity: 01-20 - DATE - 0.3704803554546018
#     Entity: 26 - CARDINAL - 0.3704803554546018
#     Entity: 720p - CARDINAL - 0.3704803554546018
#     Entity: Shiza Project & KANSAI Studio - ORG - 0.3704803554546018
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [65] (2018) WEBRip | ColdFilm
# Similarity:0.41056728436523354
#     Entity: Боруто: - ORG - 0.41056728436523354
#     Entity: Naruto Next Generations - ORG - 0.41056728436523354
#     Entity: 65 - CARDINAL - 0.41056728436523354
#     Entity: 2018 - DATE - 0.41056728436523354
#     Entity: WEBRip - GPE - 0.41056728436523354
# Data:Девственница Джейн / Jane the virgin [S02] (2015) WEB-DL 1080p | Amedia
# Similarity:0.38802395430009357
#     Entity: 2015 - DATE - 0.38802395430009357
#     Entity: WEB-DL - PERSON - 0.38802395430009357
#     Entity: Amedia - GPE - 0.38802395430009357
# Data:Девственница Джейн / Jane the virgin [S04] (2017) WEB-DLRip | Jaskier
# Similarity:0.3291426138522502
#     Entity: S04 - GPE - 0.3291426138522502
# Data:Jane The Virgin - Temporada 4 [HDTV 720p][Cap.402][AC3 5.1 Español Castellano]
# Similarity:0.39532663168637544
#     Entity: 720p][Cap.402][AC3 5.1 - CARDINAL - 0.39532663168637544
#     Entity: Español Castellano - PERSON - 0.39532663168637544
# Data:Jane-The-Virgin--Temporada-3-[HDTV][Cap-318][Espanol-Castellano]
# Similarity:0.3286709426565579
# Data:Jane The Virgin 1ª Temporada WEB-DL 720p - WWW.RAPIDOTORRENTS.COM
# Similarity:0.42839804800893155
#     Entity: Temporada WEB-DL - PERSON - 0.42839804800893155
# Data:Jane-The-Virgin--Temporada-1
# Similarity:0.3797399555133932
#     Entity: Temporada-1 - GPE - 0.3797399555133932
# Data:Jane-The-Virgin--Temporada-3-[HDTV][Cap-318][Espanol-Castellano]
# Similarity:0.3286709426565579
# Data:[ WWW.TORRENTING.ME ] - Jane.the.Virgin.S03E15.1080p.WEB-DL.DD5.1.H.264-DRACULA
# Similarity:0.3009293585799162
# Data:Jane The Virgin S02E01 720p HDTV X264-DIMENSION[CTTV]
# Similarity:0.3705972233817769
#     Entity: 720p - CARDINAL - 0.3705972233817769
# Data:Jane the Virgin S02E17 720p WEB-DL DD5 1 H264-RARBG
# Similarity:0.40114554893922033
#     Entity: 720p - CARDINAL - 0.40114554893922033
#     Entity: WEB-DL DD5 - PERSON - 0.40114554893922033
#     Entity: 1 - CARDINAL - 0.40114554893922033
# Data:Нарко: Мексика / Narcos: Mexico [S01] (2018) WEBRip | IdeaFilm
# Similarity:0.4674494448224528
#     Entity: 2018 - DATE - 0.4674494448224528
#     Entity: WEBRip - GPE - 0.4674494448224528
# Data:Narcos-Mexico-S01-[1080p]-LF
# Similarity:0.4463171056306265
#     Entity: Narcos-Mexico-S01-[1080p]-LF - PERSON - 0.4463171056306265
# Data:Narcos-Mexico-S01-FRENCH-WEBRip-x264-AMB3R
# Similarity:0.3814947745753842
#     Entity: Narcos-Mexico-S01-FRENCH-WEBRip-x264-AMB3R - PERSON - 0.3814947745753842
# Data:Narcos-Mexico-S01E08-1080p-WEB-DL-x264--ExYuSubs
# Similarity:0.26872954276512995
#     Entity: Narcos-Mexico-S01E08-1080p-WEB-DL-x264 - PERSON - 0.26872954276512995
# Data:Narcos-Mexico-S01E08-1080p-WEBRip-X264-DEFLATE
# Similarity:0.2785640111771129
#     Entity: Narcos-Mexico-S01E08-1080p-WEBRip-X264-DEFLATE - PERSON - 0.2785640111771129
# Data:Narcos Mexico - Temporada 2 [HDTV][Cap.102][www.divxtotal3.net].avi
# Similarity:0.5119879009328352
#     Entity: Narcos Mexico - Temporada 2 - PERSON - 0.5119879009328352
#     Entity: HDTV][Cap.102][www.divxtotal3.net].avi - FAC - 0.5119879009328352
# Data:Narcos-Mexico--Temporada-1-[HDTV-720p][Cap-104 106][AC3-5-1-Castellano][www-descargas2020-com]
# Similarity:0.2611076884421832
#     Entity: Narcos-Mexico - PERSON - 0.2611076884421832
# Data:[ACESSE COMANDOTORRENTS.COM] Narcos Mexico 1 ª Temporada Completa 2018 [WEB-DL] [720p] [DUAL]
# Similarity:0.37694616469748254
#     Entity: Temporada Completa - PERSON - 0.37694616469748254
#     Entity: 720p - CARDINAL - 0.37694616469748254
# Data:{WWW.BLUDV.TV} Narcos Mexico - 1ª Temporada Completa 2018 (720p) Acesse o ORIGINAL WWW.BLUDV.TV
# Similarity:0.47518538693892204
#     Entity: 2018 - DATE - 0.47518538693892204
#     Entity: 720p - CARDINAL - 0.47518538693892204
#     Entity: Acesse - NORP - 0.47518538693892204
# Data:Narcos Mexico - Temporada 2 [HDTV][Cap.101_103][Castellano][www.descargas2020.com]
# Similarity:0.4713281313644454
#     Entity: Narcos Mexico - Temporada 2 - PERSON - 0.4713281313644454
#     Entity: HDTV][Cap.101_103][Castellano][www.descargas2020.com - ORG - 0.4713281313644454
# Data:Narcos Mexico - Temporada 1 E06-E10 HDTV Castellano
# Similarity:0.5350178231147172
#     Entity: Narcos Mexico - Temporada 1 E06-E10 - PERSON - 0.5350178231147172
#     Entity: Castellano - GPE - 0.5350178231147172
# Data:The Flash 2 Temporada 1080p Dual Áudio - WWW.SOFILMESHD.NET
# Similarity:0.38223750805433243
#     Entity: 2 - CARDINAL - 0.38223750805433243
#     Entity: Dual Áudio - WWW.SOFILMESHD.NET - PERSON - 0.38223750805433243
# Data:The Flash 3ª Temporada Completa (2017) DVDR
# Similarity:0.371836338118399
#     Entity: 3ª - CARDINAL - 0.371836338118399
#     Entity: 2017 - DATE - 0.371836338118399
# Data:The-Flash--Temporada-5-[HDTV][Cap-504][Castellano][www-torrentrapid-com]
# Similarity:0.20415816015152588
#     Entity: The-Flash - ORG - 0.20415816015152588
# Data:Флэш / The Flash [S03] (2016) WEBRip | Кравец
# Similarity:0.3883929535792402
#     Entity: Флэш - GPE - 0.3883929535792402
#     Entity: The Flash [S03 - ORG - 0.3883929535792402
#     Entity: 2016 - DATE - 0.3883929535792402
#     Entity: WEBRip - GPE - 0.3883929535792402
# Data:OST - Флэш: Сезон 1 / The Flash: Season 1 (2015) MP3
# Similarity:0.3300563501177799
#     Entity: OST - Флэш: - DATE - 0.3300563501177799
#     Entity: Season 1 (2015 - DATE - 0.3300563501177799
# Data:Флэш / The Flash [S01] (2014-2015) WEB-DL 1080p | LostFilm
# Similarity:0.32549333471450465
#     Entity: Флэш - GPE - 0.32549333471450465
#     Entity: The Flash [S01] ( - ORG - 0.32549333471450465
#     Entity: 2014-2015 - DATE - 0.32549333471450465
#     Entity: WEB-DL - PERSON - 0.32549333471450465
# Data:Флэш / The Flash [S01] (2014-2015) WEB-DLRip | NewStudio
# Similarity:0.3053762858150082
#     Entity: Флэш - GPE - 0.3053762858150082
#     Entity: The Flash [S01] ( - ORG - 0.3053762858150082
#     Entity: 2014-2015 - DATE - 0.3053762858150082
#     Entity: NewStudio - ORG - 0.3053762858150082
# Data:The Flash 2014 S02E17 Flash Back 720p WEB-DL 2CH x265 HEVC-PSA mkv
# Similarity:0.35027656481844
#     Entity: 2014 - DATE - 0.35027656481844
#     Entity: 720p - CARDINAL - 0.35027656481844
#     Entity: WEB-DL - PERSON - 0.35027656481844
#     Entity: HEVC-PSA - PRODUCT - 0.35027656481844
# Data:The Flash - Season 3 - 720p HDTV - x265 HEVC - ShAaNiG
# Similarity:0.31946560468646334
#     Entity: The Flash - Season 3 - 720p - ORG - 0.31946560468646334

# %%
nlp = spacy.load('en_core_web_sm')
doc1 = nlp(u"Naruto Next Generations")

for index, row in dataset.iterrows():
    row_nlp = nlp(row.values[0])
    similarity = row_nlp.similarity(doc1)
    if similarity > 0.7:
        print ("Data:{} - Similarity:{}".format(row.values[0], similarity))
# Out:
# Data:Boruto - Naruto Next Generations - 08 - Similarity:0.7954888256413012
# Data:Boruto Naruto Next Generations E10 DUBBED HDTV x264-W4F - Similarity:0.837197512972749
# Data:Boruto Naruto Next Generations - 25 - Similarity:0.8617561136656179
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [65-78] (2018) WEBRip | ColdFilm - Similarity:0.7194620516825598
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [01x01-07 из 13] (2017) WEBRip 720p | ViruseProject - Similarity:0.7274975666805215
# Data:Boruto - Naruto Next Generations S01E13 [720p] [LEG] - COMANDOTORRENTS COM - Similarity:0.7220854329978869
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [01-04 из 13] (2017) HDTVRip 720p | SEKAI PROJECT - Similarity:0.7336552770111249
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [01-20 из 26] (2017) HDTVRip 720p | Shiza Project & KANSAI Studio - Similarity:0.7549031808492261
# Data:Боруто: Новое поколение Наруто / Boruto: Naruto Next Generations [65] (2018) WEBRip | ColdFilm - Similarity:0.7452181814115479
# Data:Jane The Virgin 1ª Temporada WEB-DL 720p - WWW.RAPIDOTORRENTS.COM - Similarity:0.7032351588196631
# Data:The Flash 3ª Temporada Completa (2017) DVDR - Similarity:0.7025759562234702

# %%
dataset
# Out:
#    Dragon-Ball-Super-S04E18-DUBBED-720p-HDTV-x264-CRiMSON[rarbg]  1
# 0   Dragon-Ball-Super-S04E28-DUBBED-720p-HDTV-x264...             1
# 1   Dragon-Ball-Super-S04E13-DUBBED-720p-HDTV-x264...             1
# 2   Dragon-Ball-Super-92-Eng-Sub-720p-2CH-AAC-x265...             2
# 3   Dragon-Ball-Super-S04E19-DUBBED-1080p-HDTV-x26...             1
# 4   Dragon-Ball-Super-E108-1080p-WEB-DL-H264-DUAL-...             2
# 5   Dragon-Ball-Super-S04E16-DUBBED-720p-HDTV-x264...             1
# 6   Dragon-Ball-Super-S05E13-DUBBED-HDTV-x264-CRiM...             1
# 7   Dragon-Ball-Super-S04E26-DUBBED-720p-HDTV-x264...             1
# 8   [Funimation-DUB]-Dragon-Ball-Super--83-[1080p]...             2
# 9   [ACESSE-MEGAFILMESTORRENTS-ORG]-Dragon-Ball-Su...             2
# 10  WWW-BLUDV-TV -Dragon-Ball-Super-2018--Episodio...             2
# 11  Dragon-Ball-Super-Complete-Season-2-1080P-BluR...             1
# 12  Dragon-Ball-Super-Complete-Season-3-1080P-BluR...             1
# 13  [HorribleSubs] Boruto - Naruto Next Generation...             2
# 14              Boruto - Naruto Next Generations - 08             2
# 15  [HorribleSubs] Boruto - Naruto Next Generation...             2
# 16   Boruto - 072 [JesuSub] vostfr 1080p x265 AAC mp4             2
# 17   Boruto - 074 [JesuSub] vostfr 1080p x265 AAC mp4             2
# 18  Catfish - 121 [sometinghere] vostfr 1080p x265...             2
# 19  Boruto Naruto Next Generations E10 DUBBED HDTV...             2
# 20                 Boruto - 009 vostfr X265 1080p mp4             2
# 21                Boruto Naruto Next Generations - 25             2
# 22  Боруто: Новое поколение Наруто / Boruto: Narut...             2
# 23  Боруто: Новое поколение Наруто / Boruto: Narut...             2
# 24  Боруто: Новое поколение Наруто / Boruto: Narut...             2
# 25  Боруто: Новое поколение Наруто / Boruto: Narut...             1
# 26  [HorribleSubs] Boruto - Naruto Next Generation...             2
# 27   Boruto - 058 [JesuSub] vostfr 1080p x265 AAC mp4             2
# 28  Boruto - Naruto Next Generations S01E13 [720p]...             1
# 29  Боруто: Новое поколение Наруто / Boruto: Narut...             2
# ..                                                ...            ..
# 32  Девственница Джейн / Jane the virgin [S02] (20...             1
# 33  Девственница Джейн / Jane the virgin [S04] (20...             1
# 34  Jane The Virgin - Temporada 4 [HDTV 720p][Cap....             3
# 35  Jane-The-Virgin--Temporada-3-[HDTV][Cap-318][E...             3
# 36  Jane The Virgin 1ª Temporada WEB-DL 720p - WWW...             3
# 37                       Jane-The-Virgin--Temporada-1             3
# 38  Jane-The-Virgin--Temporada-3-[HDTV][Cap-318][E...             3
# 39  [ WWW.TORRENTING.ME ] - Jane.the.Virgin.S03E15...             1
# 40  Jane The Virgin S02E01 720p HDTV X264-DIMENSIO...             1
# 41  Jane the Virgin S02E17 720p WEB-DL DD5 1 H264-...             1
# 42  Нарко: Мексика / Narcos: Mexico [S01] (2018) W...             1
# 43                       Narcos-Mexico-S01-[1080p]-LF             1
# 44         Narcos-Mexico-S01-FRENCH-WEBRip-x264-AMB3R             1
# 45   Narcos-Mexico-S01E08-1080p-WEB-DL-x264--ExYuSubs             1
# 46     Narcos-Mexico-S01E08-1080p-WEBRip-X264-DEFLATE             1
# 47  Narcos Mexico - Temporada 2 [HDTV][Cap.102][ww...             3
# 48  Narcos-Mexico--Temporada-1-[HDTV-720p][Cap-104...             3
# 49  [ACESSE COMANDOTORRENTS.COM] Narcos Mexico 1 ª...             3
# 50  {WWW.BLUDV.TV} Narcos Mexico - 1ª Temporada Co...             3
# 51  Narcos Mexico - Temporada 2 [HDTV][Cap.101_103...             3
# 52  Narcos Mexico - Temporada 1 E06-E10 HDTV Caste...             3
# 53  The Flash 2 Temporada 1080p Dual Áudio - WWW.S...             3
# 54        The Flash 3ª Temporada Completa (2017) DVDR             3
# 55  The-Flash--Temporada-5-[HDTV][Cap-504][Castell...             3
# 56      Флэш / The Flash [S03] (2016) WEBRip | Кравец             1
# 57  OST - Флэш: Сезон 1 / The Flash: Season 1 (201...             1
# 58  Флэш / The Flash [S01] (2014-2015) WEB-DL 1080...             1
# 59  Флэш / The Flash [S01] (2014-2015) WEB-DLRip |...             1
# 60  The Flash 2014 S02E17 Flash Back 720p WEB-DL 2...             1
# 61  The Flash - Season 3 - 720p HDTV - x265 HEVC -...             1
#
# [62 rows x 2 columns]

# %%
nlp = spacy.load('en_core_web_sm')
doc1 = nlp(u"Narcos Mexico")

for index, row in dataset.iterrows():
    row_nlp = nlp(row.values[0])
    similarity = row_nlp.similarity(doc1)
    if similarity > 0.2:
        print ("Data:{} - Similarity:{}".format(row.values[1], similarity))
# Out:
# Data:1 - Similarity:0.35956778020907215
# Data:1 - Similarity:0.36613673584127354
# Data:2 - Similarity:0.3255907234868054
# Data:1 - Similarity:0.3176832117645183
# Data:2 - Similarity:0.3757766436976939
# Data:1 - Similarity:0.39584950265042107
# Data:1 - Similarity:0.3715540354383758
# Data:1 - Similarity:0.3773204166151209
# Data:2 - Similarity:0.4691591705651836
# Data:2 - Similarity:0.32228216010002547
# Data:2 - Similarity:0.24400683223676514
# Data:1 - Similarity:0.452967575059139
# Data:1 - Similarity:0.4853667999121713
# Data:2 - Similarity:0.5556443753831516
# Data:2 - Similarity:0.638300928362744
# Data:2 - Similarity:0.5715355018908332
# Data:2 - Similarity:0.4661767752257359
# Data:2 - Similarity:0.5035055683006114
# Data:2 - Similarity:0.2967584995803762
# Data:2 - Similarity:0.7447731107838599
# Data:2 - Similarity:0.4945381240829208
# Data:2 - Similarity:0.7035856171329178
# Data:2 - Similarity:0.6183017108671955
# Data:2 - Similarity:0.6206538759653338
# Data:2 - Similarity:0.6459139858681233
# Data:1 - Similarity:0.6670639855832133
# Data:2 - Similarity:0.5470364977176844
# Data:2 - Similarity:0.4712496897490132
# Data:1 - Similarity:0.6462679299080515
# Data:2 - Similarity:0.6728693820430587
# Data:2 - Similarity:0.6843074667898643
# Data:2 - Similarity:0.6812604372246142
# Data:1 - Similarity:0.6594435652391829
# Data:1 - Similarity:0.6015334193751963
# Data:3 - Similarity:0.6356935534862115
# Data:3 - Similarity:0.5353756770507837
# Data:3 - Similarity:0.6686160019569263
# Data:3 - Similarity:0.5525898687327406
# Data:3 - Similarity:0.5353756770507837
# Data:1 - Similarity:0.39689057620236295
# Data:1 - Similarity:0.6689910932488292
# Data:1 - Similarity:0.6377571729189844
# Data:1 - Similarity:0.6049728201141861
# Data:1 - Similarity:0.674067425481403
# Data:1 - Similarity:0.5912086908346837
# Data:1 - Similarity:0.3988533523419439
# Data:1 - Similarity:0.41826224454631666
# Data:3 - Similarity:0.7675471158478523
# Data:3 - Similarity:0.42633929000526094
# Data:3 - Similarity:0.616696520007774
# Data:3 - Similarity:0.6265072021150524
# Data:3 - Similarity:0.7643424675163153
# Data:3 - Similarity:0.7592530197558456
# Data:3 - Similarity:0.6040897189854015
# Data:3 - Similarity:0.6322112472894065
# Data:3 - Similarity:0.2677266686326274
# Data:1 - Similarity:0.6218024327027017
# Data:1 - Similarity:0.4791084380969251
# Data:1 - Similarity:0.5233162331186991
# Data:1 - Similarity:0.5293263771869813
# Data:1 - Similarity:0.5631648460906603
# Data:1 - Similarity:0.4232064452552931

# %%
#!/usr/bin/env python
# coding: utf8
"""Train a convolutional neural network text classifier on the
IMDB dataset, using the TextCategorizer component. The dataset will be loaded
automatically via Thinc's built-in dataset loader. The model is added to
spacy.pipeline, and predictions are available via `doc.cats`. For more details,
see the documentation:
* Training: https://spacy.io/usage/training

Compatible with: spaCy v2.0.0+
"""
from __future__ import unicode_literals, print_function
import plac
import random
from pathlib import Path
import thinc.extra.datasets

import spacy
from spacy.util import minibatch, compounding


@plac.annotations(
    model=("Model name. Defaults to blank 'en' model.", "option", "m", str),
    output_dir=("Optional output directory", "option", "o", Path),
    n_texts=("Number of texts to train from", "option", "t", int),
    n_iter=("Number of training iterations", "option", "n", int))
def main(model=None, output_dir=None, n_iter=20, n_texts=2000):
    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()

    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank('en')  # create blank Language class
        print("Created blank 'en' model")

    # add the text classifier to the pipeline if it doesn't exist
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'textcat' not in nlp.pipe_names:
        textcat = nlp.create_pipe('textcat')
        nlp.add_pipe(textcat, last=True)
    # otherwise, get it, so we can add labels to it
    else:
        textcat = nlp.get_pipe('textcat')

    # add label to text classifier
    textcat.add_label('POSITIVE')

    # load the IMDB dataset
    print("Loading IMDB data...")
    (train_texts, train_cats), (dev_texts, dev_cats) = load_data(limit=n_texts)
    print("Using {} examples ({} training, {} evaluation)"
          .format(n_texts, len(train_texts), len(dev_texts)))
    train_data = list(zip(train_texts,
                          [{'cats': cats} for cats in train_cats]))

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'textcat']
    with nlp.disable_pipes(*other_pipes):  # only train textcat
        optimizer = nlp.begin_training()
        print("Training the model...")
        print('{:^5}\t{:^5}\t{:^5}\t{:^5}'.format('LOSS', 'P', 'R', 'F'))
        for i in range(n_iter):
            losses = {}
            # batch up the examples using spaCy's minibatch
            batches = minibatch(train_data, size=compounding(4., 32., 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                           losses=losses)
            with textcat.model.use_params(optimizer.averages):
                # evaluate on the dev data split off in load_data()
                scores = evaluate(nlp.tokenizer, textcat, dev_texts, dev_cats)
            print('{0:.3f}\t{1:.3f}\t{2:.3f}\t{3:.3f}'  # print a simple table
                  .format(losses['textcat'], scores['textcat_p'],
                          scores['textcat_r'], scores['textcat_f']))

    # test the trained model
    test_text = "This movie sucked"
    doc = nlp(test_text)
    print(test_text, doc.cats)

    if output_dir is not None:
        with nlp.use_params(optimizer.averages):
            nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

        # test the saved model
        print("Loading from", output_dir)
        nlp2 = spacy.load(output_dir)
        doc2 = nlp2(test_text)
        print(test_text, doc2.cats)


def load_data(limit=0, split=0.8):
    """Load data from the IMDB dataset."""
    # Partition off part of the train data for evaluation
    train_data, _ = thinc.extra.datasets.imdb()
    random.shuffle(train_data)
    train_data = train_data[-limit:]
    texts, labels = zip(*train_data)
    cats = [{'POSITIVE': bool(y)} for y in labels]
    split = int(len(train_data) * split)
    return (texts[:split], cats[:split]), (texts[split:], cats[split:])


def evaluate(tokenizer, textcat, texts, cats):
    docs = (tokenizer(text) for text in texts)
    tp = 0.0   # True positives
    fp = 1e-8  # False positives
    fn = 1e-8  # False negatives
    tn = 0.0   # True negatives
    for i, doc in enumerate(textcat.pipe(docs)):
        gold = cats[i]
        for label, score in doc.cats.items():
            if label not in gold:
                continue
            if score >= 0.5 and gold[label] >= 0.5:
                tp += 1.
            elif score >= 0.5 and gold[label] < 0.5:
                fp += 1.
            elif score < 0.5 and gold[label] < 0.5:
                tn += 1
            elif score < 0.5 and gold[label] >= 0.5:
                fn += 1
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f_score = 2 * (precision * recall) / (precision + recall)
    return {'textcat_p': precision, 'textcat_r': recall, 'textcat_f': f_score}


if __name__ == '__main__':
    main()
# Out:
# Created blank 'en' model
# Loading IMDB data...
# Downloading data from http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# 84115456/84125825 [============================>.] - ETA: 0sUntaring file...
# Using 2000 examples (1600 training, 400 evaluation)
# Warning: Unnamed vectors -- this won't allow multiple vectors models to be loaded. (Shape: (0, 0))
# Training the model...
# LOSS 	  P  	  R  	  F
# 68.749	0.782	0.867	0.822
# 20.339	0.825	0.862	0.843
# 7.245	0.855	0.813	0.833
# 3.152	0.856	0.823	0.839
# 1.705	0.844	0.828	0.836
# 1.135	0.850	0.837	0.844
# 0.784	0.842	0.842	0.842
# 0.716	0.837	0.857	0.847
# 0.517	0.833	0.857	0.845
# 0.475	0.834	0.842	0.838
# 0.700	0.836	0.852	0.844
# 0.518	0.850	0.837	0.844
# 0.471	0.842	0.842	0.842
# 0.324	0.842	0.842	0.842
# 0.640	0.851	0.847	0.849
# 1.107	0.855	0.842	0.849
# 0.645	0.840	0.828	0.834
# 0.303	0.853	0.828	0.840
# 0.414	0.849	0.833	0.841
# 0.914	0.854	0.833	0.843
# This movie sucked {'POSITIVE': 0.45498955249786377}
